# %% [markdown]
# # Scores

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(style="whitegrid", palette="colorblind")

# %matplotlib inline

# %% [markdown]
# ### Step 2. Create the DataFrame it should look like below.

# %%
data = {"first_name":["Jason", "Molly", "Tina", "Jake", "Amy"], "last_name":["Miller", "Jacobson", "Ali", "Milner", "Cooze"], "age":[42, 52, 36, 24, 73], "female":[0, 1, 1, 0, 1], "preTestScore":[4, 24, 31, 2, 3], "postTestScore":[25, 94, 57, 62, 70]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %% [markdown]
# ### Step 3. Create a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age
# #### Hint: Don't forget to place the labels

# %%
df.plot.scatter(x="preTestScore", y="postTestScore", s=[df.age], c="b", edgecolors="black")
plt.title("preTestScore x postTestScore")
# Out:
# Text(0.5, 1.0, 'preTestScore x postTestScore')

# %% [markdown]
# ### Step 4. Create a Scatterplot of preTestScore and postTestScore.
# ### This time the size should be 4.5 times the postTestScore and the color determined by sex

# %%
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
df.plot.scatter(x="preTestScore", y="postTestScore", s=[(df.postTestScore * 4.5)], c=df.female)
