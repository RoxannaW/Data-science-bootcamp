# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='https://covid19tracking.narrativa.com/feed_en.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# %2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A58&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf5f8120',
#     'id': '2020-5-28-10_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T09:09:07+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-610b054c543bd9f2fc095bc107d3fc06',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>632</strong> new deaths confirmed worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,646,111</strong>, with <strong>2,348,433</strong></strong> of these already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,699,933</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b> with <strong>411,821, 370,680, and 268,619</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Pakistan: 2,076</td><td>1. The US: 100,442</td><td>1. The US: 166</td><td>1. The US: 391,508</strong></td><td>1. Italy: 2,443</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. The United Kingdom: 1,379</td><td>2. The United Kingdom: 37,542</td><td>2. Italy: 117</td><td>2. Brazil: 166,647</strong></td><td>2. Mexico: 2,126</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The US: 1,352</td><td>3. Italy: 33,072</td><td>3. The United Kingdom: 82</td><td>3. Germany: 162,820</strong></td><td>3. Pakistan: 1,089</strong></td></tr></tbody></table></p><p>Moreover, <strong>9,847</strong> new positive cases have been added in the last 24 hours, which means an increase of <strong>0.17</strong>% from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,076</strong>, followed by <b>The United Kingdom</b> with <strong>1,379</strong>. <strong>The US</strong> and <strong> Argentina</strong> are not far behind, with <strong>705</strong> and <strong>705</strong> new patients respectively.</p><p> </p><p>So far, <strong>the number of COVID-19 related deaths worldwide</strong> is <strong>345,968 people</strong>, including the <strong>632</strong> new deaths over last 24 hours. <strong>The US</strong> is the country with the highest number of victims so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first reports of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, it has spread across Asia and the world. As of the latest reports, cases in China have increased to <strong>2</strong> new cases since yesterday. Overall, <strong>101</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A01&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf3cd069',
#     'id': '2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T08:08:48+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-d37eb9117490b01da834bbf873d436fe',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>345,897</strong> deaths confirmed worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The total number of people infected is now <strong>5,645,080</strong> <strong>worldwide</strong> Amongst this number, <strong>2,348,150</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,699,933</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 370,680, and 268,619</strong> cases respectively.</p><h4>Coronavirus in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Pakistan: 2,076</td><td>1. The US: 100,442</td><td>1. The US: 166</td><td>1. The US: 391,508</strong></td><td>1. Italy: 2,443</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. The United Kingdom: 1,379</td><td>2. The United Kingdom: 37,542</td><td>2. Italy: 117</td><td>2. Brazil: 166,647</strong></td><td>2. Mexico: 2,126</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The US: 1,352</td><td>3. Italy: 33,072</td><td>3. The United Kingdom: 82</td><td>3. Germany: 162,820</strong></td><td>3. Pakistan: 1,089</strong></td></tr></tbody></table></p><p>Moreover, <strong>9,178</strong> new positive cases have been reported in the last 24 hours, which means a growth of <strong>0.16</strong>% from the previous day. <strong> Pakistan</strong> has the highest number of confirmed new cases with <strong>2,076</strong>, followed by <b>The United Kingdom</b> with <strong>1,379</strong>. <strong>The US</strong> and <strong> Argentina</strong> are not far behind, with <strong>1,352</strong> and <strong>705</strong> new patients respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 345,897 people</strong> have died worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first signs of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, it has spread across the Asian continent and the globe. As of the latest reports, cases in China have grown to <strong>2</strong> new cases since Wednesday. Overall, <strong>101</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=08%3A05&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf26cd74',
#     'id': '2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
print(json_readed)
# Out:
# um=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A58&client=default_web&region=world', '_id': 'a9a97d8366303af830c81363bf5f8120', 'id': '2020-5-28-10_01-COVID-world-en_generic_COVID_EN_GENERIC'}, {'date': '2020-05-28T09:09:07+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=squ ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# um=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A58&client=default_web&region=world", "_id": "a9a97d8366303af830c81363bf5f8120", "id": "2020-5-28-10_01-COVID-world-en_generic_COVID_EN_GENERIC"}, {"date": "2020-05-28T09:09:07+02:00", "metadata": {"picurl_square_spain": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default", "picurl_square_spain_extended": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true", "graphs": {"graph_picurl_china": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png", "graph_picurl_us": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png", "graph_picurl_deaths_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png", "graph_picurl_world": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png", "graph_picurl_china_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png", "graph_picurl_us_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png", "graph_picurl_spain_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png", "graph_picurl_us_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png", "graph_picurl_deaths_log_evolution": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png", "graph_picurl_italy": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png", "graph_picurl_italy_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png", "graph_picurl_us_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png", "graph_picurl_italy_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png", "graph_picurl_china_deaths": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png", "graph_picurl_italy_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png", "graph_picurl_spain_confirmed": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png", "graph_picurl_china_recovered": "https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png"}, "picurl_square_world": "https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default", "picurl_16_9_spain": "https://4i2g925ohj.exe ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# %2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A58&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf5f8120',
#     'id': '2020-5-28-10_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T09:09:07+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-610b054c543bd9f2fc095bc107d3fc06',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>632</strong> new deaths confirmed worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The number of COVID-19 cases worldwide is now at <strong>5,646,111</strong>, with <strong>2,348,433</strong></strong> of these already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> has the most cases with <strong>1,699,933</strong>, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b> with <strong>411,821, 370,680, and 268,619</strong> cases respectively.</p><h4>Status in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Pakistan: 2,076</td><td>1. The US: 100,442</td><td>1. The US: 166</td><td>1. The US: 391,508</strong></td><td>1. Italy: 2,443</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. The United Kingdom: 1,379</td><td>2. The United Kingdom: 37,542</td><td>2. Italy: 117</td><td>2. Brazil: 166,647</strong></td><td>2. Mexico: 2,126</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The US: 1,352</td><td>3. Italy: 33,072</td><td>3. The United Kingdom: 82</td><td>3. Germany: 162,820</strong></td><td>3. Pakistan: 1,089</strong></td></tr></tbody></table></p><p>Moreover, <strong>9,847</strong> new positive cases have been added in the last 24 hours, which means an increase of <strong>0.17</strong>% from the previous day. <strong> Pakistan</strong> is the country with the most new cases, having now confirmed <strong>2,076</strong>, followed by <b>The United Kingdom</b> with <strong>1,379</strong>. <strong>The US</strong> and <strong> Argentina</strong> are not far behind, with <strong>705</strong> and <strong>705</strong> new patients respectively.</p><p> </p><p>So far, <strong>the number of COVID-19 related deaths worldwide</strong> is <strong>345,968 people</strong>, including the <strong>632</strong> new deaths over last 24 hours. <strong>The US</strong> is the country with the highest number of victims so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first reports of this new strain of the virus appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, it has spread across Asia and the world. As of the latest reports, cases in China have increased to <strong>2</strong> new cases since yesterday. Overall, <strong>101</strong> people are infected with coronavirus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A01&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf3cd069',
#     'id': '2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC'},
#    {'date': '2020-05-28T08:08:48+02:00',
#     'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default',
#      'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#      'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#       'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#       'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#       'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#       'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#       'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#       'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#       'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#       'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#       'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#       'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#       'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#       'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#       'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#       'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#       'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#       'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#      'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default',
#      'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default',
#      'composition_type': 'world',
#      'country_selected': None,
#      'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#      'state_selected': None},
#     'author': 'Narrativa',
#     '_rev': '1-d37eb9117490b01da834bbf873d436fe',
#     'language': 'en_generic',
#     'title': 'Coronavirus outbreak latest: <strong>345,897</strong> deaths confirmed worldwide',
#     'content': '<p><small>Narrativa | Thursday, May 28, 2020 </small></p><p>The total number of people infected is now <strong>5,645,080</strong> <strong>worldwide</strong> Amongst this number, <strong>2,348,150</strong></strong> have already recovered, according to the data <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">provided by Johns Hopkins University</a>. <b>The US</b> tops the list with <strong>1,699,933</strong> recorded cases, followed by <b> Brazil</b>, <b> Russia</b>, and <b>The United Kingdom</b>, who have confirmed <strong>411,821, 370,680, and 268,619</strong> cases respectively.</p><h4>Coronavirus in the world</h4><p><table width="100%"><thead><tr><th><strong>Active Cases</strong></th><th colspan="2"><strong>Infected</strong></th><th colspan="2"><strong>Deaths</strong></th><th colspan="2"><strong>Recovered</strong></th></tr><tr><th>Total</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th><th>Total</th><th>Last 24h</th></tr></thead><tbody><tr><td>1. The US: 1,207,983</td><td>1. The US: 1,699,933</td><td>1. Pakistan: 2,076</td><td>1. The US: 100,442</td><td>1. The US: 166</td><td>1. The US: 391,508</strong></td><td>1. Italy: 2,443</strong></td></tr><tr><td>2. The United Kingdom: 229,911</td><td>2. Brazil: 411,821</td><td>2. The United Kingdom: 1,379</td><td>2. The United Kingdom: 37,542</td><td>2. Italy: 117</td><td>2. Brazil: 166,647</strong></td><td>2. Mexico: 2,126</strong></td></tr><tr><td>3. Russia: 224,504</td><td>3. Russia: 370,680</td><td>3. The US: 1,352</td><td>3. Italy: 33,072</td><td>3. The United Kingdom: 82</td><td>3. Germany: 162,820</strong></td><td>3. Pakistan: 1,089</strong></td></tr></tbody></table></p><p>Moreover, <strong>9,178</strong> new positive cases have been reported in the last 24 hours, which means a growth of <strong>0.16</strong>% from the previous day. <strong> Pakistan</strong> has the highest number of confirmed new cases with <strong>2,076</strong>, followed by <b>The United Kingdom</b> with <strong>1,379</strong>. <strong>The US</strong> and <strong> Argentina</strong> are not far behind, with <strong>1,352</strong> and <strong>705</strong> new patients respectively.</p><p> </p><p>Since the coronavirus outbreak started, a total of<strong> 345,897 people</strong> have died worldwide. <strong>The US</strong> is the country with the highest count so far with <strong>100,442</strong> deaths, followed by <strong>The United Kingdom, Italy, and Spain</strong> with <strong>37,542, 33,072, and 27,940</strong> deaths respectively.</p><p>The first signs of COVID-19 appeared in <strong>China</strong>, in the city of <strong>Wuhan</strong>, on <strong>31 December 2019</strong>. Since then, it has spread across the Asian continent and the globe. As of the latest reports, cases in China have grown to <strong>2</strong> new cases since Wednesday. Overall, <strong>101</strong> people are infected with the virus.</p><hr><p><strong>Note</strong>: This article has been <strong><u>generated automatically by <a href="https://www.narrativa.com" target="_blank">Narrativa</a></u></strong> from the data by <a href="https://www.mscbs.gob.es/profesionales/saludPublica/ccayes/alertasActual/nCov-China/situacionActual.htm" target="_blank">Ministerio de Sanidad</a>, <a href="https://github.com/pcm-dpc/COVID-19" target="_blank">Dipartimento della Protezione Civile de Italia</a>, <a href="https://www.rki.de/DE/Content/InfAZ/N/Neuartiges_Coronavirus/Situationsberichte/Gesamt.html" target="_blank">Robert Koch Institute</a> and <a href="https://systems.jhu.edu/research/public-health/ncov/" target="_blank">Johns Hopkins University</a>.</p>',
#     'picurl_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.%3A%201%2C699%2C933&top_paises2=Brasil%3A%20411%2C821&top_paises3=Rusia%3A%20370%2C680&client=default&region=world',
#     'picurl': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_comunidades=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&client=default&region=spain',
#     'metatitle': '',
#     'subtitle': '',
#     'picurl_banner_web': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&region_confirmed_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=08%3A05&client=default_web&region=world',
#     '_id': 'a9a97d8366303af830c81363bf26cd74',
#     'id': '2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC'}]}}

# %%
df_json = pd.read_json("data_indented.json")
df_json

df_json.reset_index()
# Out:
#   index                                               data
# 0  post  [{'date': '2020-07-13T12:02:36+02:00', 'metada...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    for dict_ in json_readed['data']['post']:
        print(dict_)
# Out:
# med_num=233%2C037&region_confirmed_today_num=344&region_deaths_today_num=48&region_deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&top_paises1=EE.UU.&top_paises2=Brasil&top_paises3=Rusia&top_paises1_num=1%2C699%2C933&top_paises2_num=411%2C821&top_paises3_num=370%2C680&top_comunidades1=Madrid&top_comunidades2=Catalu%C3%B1a&top_comunidades3=Castilla%20y%20Le%C3%B3n&top_comunidades1_num=67%2C049&top_comunidades2_num=55%2C888&top_comunidades3_num=18%2C627&gen_date=2020/05/28&gen_time=09%3A58&client=default_web&region=world', '_id': 'a9a97d8366303af830c81363bf5f8120', 'id': '2020-5-28-10_01-COVID-world-en_generic_COVID_EN_GENERIC'}
# {'date': '2020-05-28T09:09:07+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-09_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&actives_num=2%2C951%2C710&recovered_num=2%2C348%2C433&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C646%2C111&deaths_num=345%2C968&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num= ...
# {'date': '2020-05-28T08:08:48+02:00', 'metadata': {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&actives_num=54%2C721&recovered_num=150%2C376&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default', 'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=233%2C037&confirmed_today_num=344&deaths_today_num=48&deaths_num=27%2C940&date=28%20de%20mayo%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true', 'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png', 'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png', 'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png', 'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png', 'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png', 'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png', 'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png', 'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png', 'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png', 'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png', 'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png', 'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png', 'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png', 'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png', 'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png', 'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png', 'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-5-28-08_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'}, 'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&actives_num=2%2C951%2C033&recovered_num=2%2C348%2C150&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&region=world&aspect_ratio=square&client=default', 'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=5%2C645%2C080&deaths_num=345%2C897&date=28%20de%20mayo%20del%202020&top_countries=EE.UU.%20%281%2C699%2C933%29%2C%20Brasil%20%28411%2C821%29%2C%20Rusia%20%28370%2C680%29&top_spain=Madrid%20%2867%2C049%29%2C%20Catalu%C3%B1a%20%2855%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2818%2C627%29&region=spain&aspect_ratio=16_9&client=default', 'composition_type': 'world', 'country_selected': None, 'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num= ...

# %%
with open('data_indented.json', 'r') as outfile:
    json_readed = json.load(outfile)
    new_json = json_readed['data']['post']

# %%
with open('new_json', 'w+') as outfile:
    json.dump(new_json, outfile, indent=4)

# %%
df_new_json = pd.read_json("new_json")
df_new_json
# Out:
#                          date  \
# 0   2020-07-13 12:02:36+02:00
# 1   2020-07-13 11:04:40+02:00
# 2   2020-07-13 10:02:47+02:00
# 3   2020-07-13 09:02:46+02:00
# 4   2020-07-13 08:03:17+02:00
# ..                        ...
# 995 2020-05-28 12:26:05+02:00
# 996 2020-05-28 11:12:24+02:00
# 997 2020-05-28 10:03:05+02:00
# 998 2020-05-28 09:09:07+02:00
# 999 2020-05-28 08:08:48+02:00
#
#                                               metadata     author  \
# 0    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 1    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 2    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 3    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 4    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# ..                                                 ...        ...
# 995  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 996  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 997  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 998  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 999  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
#
#                                    _rev    language  \
# 0    1-7ca8cdc55e3c11a3b7bb6fb2b3c66dec  en_generic
# 1    1-3df4246465bf5530bc239ab76b50f13c  en_generic
# 2    1-68604095894b6248df3053ed5329fd4e  en_generic
# 3    1-31d30c7351b0469a546a5ab36b18cbde  en_generic
# 4    1-5cd595d6af4e3a118a5486147124c0fd  en_generic
# ..                                  ...         ...
# 995  1-27b05d532847f3930e2e4e0acf24eb37  en_generic
# 996  1-a1239b5a66ac760645e6cc98f88c8df5  en_generic
# 997  1-f500814f27c8104412e4eb99c1dfd877  en_generic
# 998  1-610b054c543bd9f2fc095bc107d3fc06  en_generic
# 999  1-d37eb9117490b01da834bbf873d436fe  en_generic
#
#                                                  title  \
# 0    Coronavirus outbreak latest: <strong>714</stro...
# 1    Coronavirus outbreak latest: <strong>557,948</...
# 2    Coronavirus outbreak latest: <strong>12,848,94...
# 3    Coronavirus outbreak latest: <strong>714</stro...
# 4    Coronavirus outbreak latest: <strong>12,848,78...
# ..                                                 ...
# 995  Coronavirus outbreak latest: <strong>22,604</s...
# 996  Coronavirus outbreak latest: <strong>20,647</s...
# 997  Coronavirus outbreak latest: <strong>11,212</s...
# 998  Coronavirus outbreak latest: <strong>632</stro...
# 999  Coronavirus outbreak latest: <strong>345,897</...
#
#                                                content  \
# 0    <p><small>Narrativa | Monday, July 13, 2020 </...
# 1    <p><small>Narrativa | Monday, July 13, 2020 </...
# 2    <p><small>Narrativa | Monday, July 13, 2020 </...
# 3    <p><small>Narrativa | Monday, July 13, 2020 </...
# 4    <p><small>Narrativa | Monday, July 13, 2020 </...
# ..                                                 ...
# 995  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 996  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 997  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 998  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 999  <p><small>Narrativa | Thursday, May 28, 2020 <...
#
#                                           picurl_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                 picurl metatitle subtitle  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...       ...      ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                      picurl_banner_web  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                   _id  \
# 0    95a8dfdaec69cd5225aad0c2ef299573
# 1    95a8dfdaec69cd5225aad0c2ef0eb40f
# 2    2b4a5933a22c7a627d22dae234c5859f
# 3    2b4a5933a22c7a627d22dae234b541e6
# 4    2b4a5933a22c7a627d22dae234af2a5d
# ..                                ...
# 995  a9a97d8366303af830c81363bfe2ef34
# 996  a9a97d8366303af830c81363bf97adcb
# 997  a9a97d8366303af830c81363bf5f8120
# 998  a9a97d8366303af830c81363bf3cd069
# 999  a9a97d8366303af830c81363bf26cd74
#
#                                                     id
# 0    2020-7-13-12_01-COVID-world-en_generic_COVID_E...
# 1    2020-7-13-11_01-COVID-world-en_generic_COVID_E...
# 2    2020-7-13-10_01-COVID-world-en_generic_COVID_E...
# 3    2020-7-13-09_01-COVID-world-en_generic_COVID_E...
# 4    2020-7-13-08_01-COVID-world-en_generic_COVID_E...
# ..                                                 ...
# 995  2020-5-28-12_01-COVID-world-en_generic_COVID_E...
# 996  2020-5-28-11_01-COVID-world-en_generic_COVID_E...
# 997  2020-5-28-10_01-COVID-world-en_generic_COVID_E...
# 998  2020-5-28-09_01-COVID-world-en_generic_COVID_E...
# 999  2020-5-28-08_01-COVID-world-en_generic_COVID_E...
#
# [1000 rows x 14 columns]

# %%
final_df = pd.concat([df_json, df_new_json], axis=1)

final_df
# Out:
#                                                    data  \
# post  [{'date': '2020-07-13T12:02:36+02:00', 'metada...
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# ...                                                 ...
# 995                                                 NaN
# 996                                                 NaN
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
#
#                           date  \
# post                       NaT
# 0    2020-07-13 12:02:36+02:00
# 1    2020-07-13 11:04:40+02:00
# 2    2020-07-13 10:02:47+02:00
# 3    2020-07-13 09:02:46+02:00
# ...                        ...
# 995  2020-05-28 12:26:05+02:00
# 996  2020-05-28 11:12:24+02:00
# 997  2020-05-28 10:03:05+02:00
# 998  2020-05-28 09:09:07+02:00
# 999  2020-05-28 08:08:48+02:00
#
#                                                metadata     author  \
# post                                                NaN        NaN
# 0     {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 1     {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 2     {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 3     {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# ...                                                 ...        ...
# 995   {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 996   {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 997   {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 998   {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 999   {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
#
#                                     _rev    language  \
# post                                 NaN         NaN
# 0     1-7ca8cdc55e3c11a3b7bb6fb2b3c66dec  en_generic
# 1     1-3df4246465bf5530bc239ab76b50f13c  en_generic
# 2     1-68604095894b6248df3053ed5329fd4e  en_generic
# 3     1-31d30c7351b0469a546a5ab36b18cbde  en_generic
# ...                                  ...         ...
# 995   1-27b05d532847f3930e2e4e0acf24eb37  en_generic
# 996   1-a1239b5a66ac760645e6cc98f88c8df5  en_generic
# 997   1-f500814f27c8104412e4eb99c1dfd877  en_generic
# 998   1-610b054c543bd9f2fc095bc107d3fc06  en_generic
# 999   1-d37eb9117490b01da834bbf873d436fe  en_generic
#
#                                                   title  \
# post                                                NaN
# 0     Coronavirus outbreak latest: <strong>714</stro...
# 1     Coronavirus outbreak latest: <strong>557,948</...
# 2     Coronavirus outbreak latest: <strong>12,848,94...
# 3     Coronavirus outbreak latest: <strong>714</stro...
# ...                                                 ...
# 995   Coronavirus outbreak latest: <strong>22,604</s...
# 996   Coronavirus outbreak latest: <strong>20,647</s...
# 997   Coronavirus outbreak latest: <strong>11,212</s...
# 998   Coronavirus outbreak latest: <strong>632</stro...
# 999   Coronavirus outbreak latest: <strong>345,897</...
#
#                                                 content  \
# post                                                NaN
# 0     <p><small>Narrativa | Monday, July 13, 2020 </...
# 1     <p><small>Narrativa | Monday, July 13, 2020 </...
# 2     <p><small>Narrativa | Monday, July 13, 2020 </...
# 3     <p><small>Narrativa | Monday, July 13, 2020 </...
# ...                                                 ...
# 995   <p><small>Narrativa | Thursday, May 28, 2020 <...
# 996   <p><small>Narrativa | Thursday, May 28, 2020 <...
# 997   <p><small>Narrativa | Thursday, May 28, 2020 <...
# 998   <p><small>Narrativa | Thursday, May 28, 2020 <...
# 999   <p><small>Narrativa | Thursday, May 28, 2020 <...
#
#                                            picurl_world  \
# post                                                NaN
# 0     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...
# 995   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999   https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                  picurl metatitle subtitle  \
# post                                                NaN       NaN      NaN
# 0     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...       ...      ...
# 995   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999   https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                       picurl_banner_web  \
# post                                                NaN
# 0     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3     https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ...                                                 ...
# 995   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998   https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999   https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                    _id  \
# post                               NaN
# 0     95a8dfdaec69cd5225aad0c2ef299573
# 1     95a8dfdaec69cd5225aad0c2ef0eb40f
# 2     2b4a5933a22c7a627d22dae234c5859f
# 3     2b4a5933a22c7a627d22dae234b541e6
# ...                                ...
# 995   a9a97d8366303af830c81363bfe2ef34
# 996   a9a97d8366303af830c81363bf97adcb
# 997   a9a97d8366303af830c81363bf5f8120
# 998   a9a97d8366303af830c81363bf3cd069
# 999   a9a97d8366303af830c81363bf26cd74
#
#                                                      id
# post                                                NaN
# 0     2020-7-13-12_01-COVID-world-en_generic_COVID_E...
# 1     2020-7-13-11_01-COVID-world-en_generic_COVID_E...
# 2     2020-7-13-10_01-COVID-world-en_generic_COVID_E...
# 3     2020-7-13-09_01-COVID-world-en_generic_COVID_E...
# ...                                                 ...
# 995   2020-5-28-12_01-COVID-world-en_generic_COVID_E...
# 996   2020-5-28-11_01-COVID-world-en_generic_COVID_E...
# 997   2020-5-28-10_01-COVID-world-en_generic_COVID_E...
# 998   2020-5-28-09_01-COVID-world-en_generic_COVID_E...
# 999   2020-5-28-08_01-COVID-world-en_generic_COVID_E...
#
# [1001 rows x 15 columns]

# %%
for elem in new_json[0]["metadata"]:
    print(elem)
# Out:
# picurl_square_spain
# picurl_square_spain_extended
# graphs
# picurl_square_world
# picurl_16_9_spain
# composition_type
# country_selected
# picurl_square_world_extended
# state_selected

# %%
another_json = new_json[0]["metadata"]
another_json
# Out:
# {'picurl_square_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&actives_num=216%2C926&recovered_num=8%2C579&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default',
#  'picurl_square_spain_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=253%2C908&confirmed_today_num=0&deaths_today_num=0&deaths_num=28%2C403&date=13%20de%20julio%20del%202020&region=spain&aspect_ratio=square&client=default&extended=true',
#  'graphs': {'graph_picurl_china': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china.png',
#   'graph_picurl_us': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us.png',
#   'graph_picurl_deaths_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_evolution.png',
#   'graph_picurl_world': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_world.png',
#   'graph_picurl_china_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_confirmed.png',
#   'graph_picurl_us_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_confirmed.png',
#   'graph_picurl_spain_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_deaths.png',
#   'graph_picurl_us_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_recovered.png',
#   'graph_picurl_deaths_log_evolution': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_deaths_log_evolution.png',
#   'graph_picurl_italy': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy.png',
#   'graph_picurl_italy_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_recovered.png',
#   'graph_picurl_us_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_us_deaths.png',
#   'graph_picurl_italy_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_deaths.png',
#   'graph_picurl_china_deaths': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_deaths.png',
#   'graph_picurl_italy_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_italy_confirmed.png',
#   'graph_picurl_spain_confirmed': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_spain_confirmed.png',
#   'graph_picurl_china_recovered': 'https://resources.gabriele.ai/coronavirus/2020-7-13-12_01-COVID-world-en_generic_COVID_EN_GENERIC_china_recovered.png'},
#  'picurl_square_world': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C848%2C940&actives_num=5%2C321%2C549&recovered_num=6%2C969%2C443&deaths_num=557%2C948&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default',
#  'picurl_16_9_spain': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C848%2C940&deaths_num=557%2C948&date=13%20de%20julio%20del%202020&top_countries=EE.UU.%20%283%2C304%2C942%29%2C%20Brasil%20%281%2C864%2C681%29%2C%20India%20%28879%2C365%29&top_spain=Madrid%20%2872%2C532%29%2C%20Catalu%C3%B1a%20%2863%2C888%29%2C%20Castilla%20y%20Le%C3%B3n%20%2819%2C787%29&region=spain&aspect_ratio=16_9&client=default',
#  'composition_type': 'world',
#  'country_selected': None,
#  'picurl_square_world_extended': 'https://4i2g925ohj.execute-api.eu-west-3.amazonaws.com/pro/coronavirus?confirmed_num=12%2C848%2C940&actives_num=5%2C321%2C549&recovered_num=6%2C969%2C443&deaths_num=557%2C948&date=13%20de%20julio%20del%202020&region=world&aspect_ratio=square&client=default&extended=true',
#  'state_selected': None}

# %%
print(type(json_readed['data']['post']))
print(type(json_readed['data']))
print(type(json_readed))
# Out:
# <class 'list'>
# <class 'dict'>
# <class 'dict'>

# %%
with open('another_json', 'w+') as outfile:
    json.dump(another_json, outfile, indent=4)

# %%
df_another_json = pd.read_json("another_json")
df_another_json = df_another_json.reset_index()

# %%
final_df_1 = pd.concat([df_new_json, df_another_json], axis=1)

# %%
final_df_1
# Out:
#                          date  \
# 0   2020-07-13 12:02:36+02:00
# 1   2020-07-13 11:04:40+02:00
# 2   2020-07-13 10:02:47+02:00
# 3   2020-07-13 09:02:46+02:00
# 4   2020-07-13 08:03:17+02:00
# ..                        ...
# 995 2020-05-28 12:26:05+02:00
# 996 2020-05-28 11:12:24+02:00
# 997 2020-05-28 10:03:05+02:00
# 998 2020-05-28 09:09:07+02:00
# 999 2020-05-28 08:08:48+02:00
#
#                                               metadata     author  \
# 0    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 1    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 2    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 3    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 4    {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# ..                                                 ...        ...
# 995  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 996  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 997  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 998  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
# 999  {'picurl_square_spain': 'https://4i2g925ohj.ex...  Narrativa
#
#                                    _rev    language  \
# 0    1-7ca8cdc55e3c11a3b7bb6fb2b3c66dec  en_generic
# 1    1-3df4246465bf5530bc239ab76b50f13c  en_generic
# 2    1-68604095894b6248df3053ed5329fd4e  en_generic
# 3    1-31d30c7351b0469a546a5ab36b18cbde  en_generic
# 4    1-5cd595d6af4e3a118a5486147124c0fd  en_generic
# ..                                  ...         ...
# 995  1-27b05d532847f3930e2e4e0acf24eb37  en_generic
# 996  1-a1239b5a66ac760645e6cc98f88c8df5  en_generic
# 997  1-f500814f27c8104412e4eb99c1dfd877  en_generic
# 998  1-610b054c543bd9f2fc095bc107d3fc06  en_generic
# 999  1-d37eb9117490b01da834bbf873d436fe  en_generic
#
#                                                  title  \
# 0    Coronavirus outbreak latest: <strong>714</stro...
# 1    Coronavirus outbreak latest: <strong>557,948</...
# 2    Coronavirus outbreak latest: <strong>12,848,94...
# 3    Coronavirus outbreak latest: <strong>714</stro...
# 4    Coronavirus outbreak latest: <strong>12,848,78...
# ..                                                 ...
# 995  Coronavirus outbreak latest: <strong>22,604</s...
# 996  Coronavirus outbreak latest: <strong>20,647</s...
# 997  Coronavirus outbreak latest: <strong>11,212</s...
# 998  Coronavirus outbreak latest: <strong>632</stro...
# 999  Coronavirus outbreak latest: <strong>345,897</...
#
#                                                content  \
# 0    <p><small>Narrativa | Monday, July 13, 2020 </...
# 1    <p><small>Narrativa | Monday, July 13, 2020 </...
# 2    <p><small>Narrativa | Monday, July 13, 2020 </...
# 3    <p><small>Narrativa | Monday, July 13, 2020 </...
# 4    <p><small>Narrativa | Monday, July 13, 2020 </...
# ..                                                 ...
# 995  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 996  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 997  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 998  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 999  <p><small>Narrativa | Thursday, May 28, 2020 <...
#
#                                           picurl_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                 picurl metatitle  ...  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# ..                                                 ...       ...  ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...            ...
#
#                              index  \
# 0               graph_picurl_china
# 1     graph_picurl_china_confirmed
# 2        graph_picurl_china_deaths
# 3     graph_picurl_china_recovered
# 4    graph_picurl_deaths_evolution
# ..                             ...
# 995                            NaN
# 996                            NaN
# 997                            NaN
# 998                            NaN
# 999                            NaN
#
#                                    picurl_square_spain  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                           picurl_square_spain_extended  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                                 graphs  \
# 0    https://resources.gabriele.ai/coronavirus/2020...
# 1    https://resources.gabriele.ai/coronavirus/2020...
# 2    https://resources.gabriele.ai/coronavirus/2020...
# 3    https://resources.gabriele.ai/coronavirus/2020...
# 4    https://resources.gabriele.ai/coronavirus/2020...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                    picurl_square_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                      picurl_16_9_spain composition_type  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# ..                                                 ...              ...
# 995                                                NaN              NaN
# 996                                                NaN              NaN
# 997                                                NaN              NaN
# 998                                                NaN              NaN
# 999                                                NaN              NaN
#
#     country_selected                       picurl_square_world_extended  \
# 0                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..               ...                                                ...
# 995              NaN                                                NaN
# 996              NaN                                                NaN
# 997              NaN                                                NaN
# 998              NaN                                                NaN
# 999              NaN                                                NaN
#
#     state_selected
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 995            NaN
# 996            NaN
# 997            NaN
# 998            NaN
# 999            NaN
#
# [1000 rows x 24 columns]

# %%
final_df_1 = final_df_1.drop(["metadata"], axis=1)

# %%
final_df_1
# Out:
#                          date     author                                _rev  \
# 0   2020-07-13 12:02:36+02:00  Narrativa  1-7ca8cdc55e3c11a3b7bb6fb2b3c66dec
# 1   2020-07-13 11:04:40+02:00  Narrativa  1-3df4246465bf5530bc239ab76b50f13c
# 2   2020-07-13 10:02:47+02:00  Narrativa  1-68604095894b6248df3053ed5329fd4e
# 3   2020-07-13 09:02:46+02:00  Narrativa  1-31d30c7351b0469a546a5ab36b18cbde
# 4   2020-07-13 08:03:17+02:00  Narrativa  1-5cd595d6af4e3a118a5486147124c0fd
# ..                        ...        ...                                 ...
# 995 2020-05-28 12:26:05+02:00  Narrativa  1-27b05d532847f3930e2e4e0acf24eb37
# 996 2020-05-28 11:12:24+02:00  Narrativa  1-a1239b5a66ac760645e6cc98f88c8df5
# 997 2020-05-28 10:03:05+02:00  Narrativa  1-f500814f27c8104412e4eb99c1dfd877
# 998 2020-05-28 09:09:07+02:00  Narrativa  1-610b054c543bd9f2fc095bc107d3fc06
# 999 2020-05-28 08:08:48+02:00  Narrativa  1-d37eb9117490b01da834bbf873d436fe
#
#        language                                              title  \
# 0    en_generic  Coronavirus outbreak latest: <strong>714</stro...
# 1    en_generic  Coronavirus outbreak latest: <strong>557,948</...
# 2    en_generic  Coronavirus outbreak latest: <strong>12,848,94...
# 3    en_generic  Coronavirus outbreak latest: <strong>714</stro...
# 4    en_generic  Coronavirus outbreak latest: <strong>12,848,78...
# ..          ...                                                ...
# 995  en_generic  Coronavirus outbreak latest: <strong>22,604</s...
# 996  en_generic  Coronavirus outbreak latest: <strong>20,647</s...
# 997  en_generic  Coronavirus outbreak latest: <strong>11,212</s...
# 998  en_generic  Coronavirus outbreak latest: <strong>632</stro...
# 999  en_generic  Coronavirus outbreak latest: <strong>345,897</...
#
#                                                content  \
# 0    <p><small>Narrativa | Monday, July 13, 2020 </...
# 1    <p><small>Narrativa | Monday, July 13, 2020 </...
# 2    <p><small>Narrativa | Monday, July 13, 2020 </...
# 3    <p><small>Narrativa | Monday, July 13, 2020 </...
# 4    <p><small>Narrativa | Monday, July 13, 2020 </...
# ..                                                 ...
# 995  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 996  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 997  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 998  <p><small>Narrativa | Thursday, May 28, 2020 <...
# 999  <p><small>Narrativa | Thursday, May 28, 2020 <...
#
#                                           picurl_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#                                                 picurl metatitle subtitle  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...       ...      ...
# 995  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 996  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 997  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 998  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 999  https://4i2g925ohj.execute-api.eu-west-3.amazo...
#
#      ...                          index  \
# 0    ...             graph_picurl_china
# 1    ...   graph_picurl_china_confirmed
# 2    ...      graph_picurl_china_deaths
# 3    ...   graph_picurl_china_recovered
# 4    ...  graph_picurl_deaths_evolution
# ..   ...                            ...
# 995  ...                            NaN
# 996  ...                            NaN
# 997  ...                            NaN
# 998  ...                            NaN
# 999  ...                            NaN
#
#                                    picurl_square_spain  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                           picurl_square_spain_extended  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                                 graphs  \
# 0    https://resources.gabriele.ai/coronavirus/2020...
# 1    https://resources.gabriele.ai/coronavirus/2020...
# 2    https://resources.gabriele.ai/coronavirus/2020...
# 3    https://resources.gabriele.ai/coronavirus/2020...
# 4    https://resources.gabriele.ai/coronavirus/2020...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                    picurl_square_world  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..                                                 ...
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
# 998                                                NaN
# 999                                                NaN
#
#                                      picurl_16_9_spain composition_type  \
# 0    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 1    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 2    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 3    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# 4    https://4i2g925ohj.execute-api.eu-west-3.amazo...            world
# ..                                                 ...              ...
# 995                                                NaN              NaN
# 996                                                NaN              NaN
# 997                                                NaN              NaN
# 998                                                NaN              NaN
# 999                                                NaN              NaN
#
#     country_selected                       picurl_square_world_extended  \
# 0                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 1                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 2                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 3                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# 4                NaN  https://4i2g925ohj.execute-api.eu-west-3.amazo...
# ..               ...                                                ...
# 995              NaN                                                NaN
# 996              NaN                                                NaN
# 997              NaN                                                NaN
# 998              NaN                                                NaN
# 999              NaN                                                NaN
#
#     state_selected
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 995            NaN
# 996            NaN
# 997            NaN
# 998            NaN
# 999            NaN
#
# [1000 rows x 23 columns]
