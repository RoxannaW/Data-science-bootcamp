# %% [markdown]
# ## Working on Jsons

# %%
import requests
import json
import pandas as pd

# %%
r = requests.get(url='http://data.nba.net/prod/v2/2018/teams.json')
json_readed = json.loads(r.text)
json_readed
# Out:
# onfName': 'West',
#     'divName': 'Pacific'},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Guangzhou',
#     'altCityName': 'Guangzhou',
#     'fullName': 'Guangzhou Long-Lions',
#     'tricode': 'GUA',
#     'teamId': '15018',
#     'nickname': 'Long-Lions',
#     'urlName': 'long-lions',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Haifa',
#     'altCityName': 'Haifa',
#     'fullName': 'Maccabi Haifa',
#     'tricode': 'MAC',
#     'teamId': '93',
#     'nickname': 'Maccabi Haifa',
#     'urlName': 'maccabi_haifa',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': True,
#     'isAllStar': False,
#     'city': 'Houston',
#     'altCityName': 'Houston',
#     'fullName': 'Houston Rockets',
#     'tricode': 'HOU',
#     'teamId': '1610612745',
#     'nickname': 'Rockets',
#     'urlName': 'rockets',
#     'confName': 'West',
#     'divName': 'Southwest'},
# ...

# %%
print(json_readed)
# Out:
# se, 'city': 'Adelaide', 'altCityName': 'Adelaide', 'fullName': 'Adelaide 36ers', 'tricode': 'ADL', 'teamId': '15019', 'nickname': '36ers', 'urlName': '36ers', 'confName': 'Intl', 'divName': ''}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Atlanta', 'altCityName': 'Atlanta', 'fullName': 'Atlanta Hawks', 'tricode': 'ATL', 'teamId': '1610612737', 'nickname': 'Hawks', 'urlName': 'hawks', 'confName': 'East', 'divName': 'Southeast'}, {'isNBAFranchise': False, 'isAllStar': False, 'city': 'Beijing', 'altCityName': 'Beijing', 'fullName': 'Beijing Ducks', 'tricode': 'BJD', 'teamId': '15021', 'nickname': 'Ducks', 'urlName': 'ducks', 'confName': 'Intl', 'divName': ''}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Boston', 'altCityName': 'Boston', 'fullName': 'Boston Celtics', 'tricode': 'BOS', 'teamId': '1610612738', 'nickname': 'Celtics', 'urlName': 'celtics', 'confName': 'East', 'divName': 'Atlantic'}, {'isNBAFranchise': True, 'isAllStar': False, 'city': 'Brooklyn', 'altCity
# ...

# %% [markdown]
# Save json in a local file called "data.json"

# %%
with open('data.json', 'w+') as outfile:
    json.dump(json_readed, outfile)

# %%
with open('data.json') as f:
    line = f.readline()
    if line:
        print(line)
        line = f.readline()
print(line)
# Out:
# e, "city": "Adelaide", "altCityName": "Adelaide", "fullName": "Adelaide 36ers", "tricode": "ADL", "teamId": "15019", "nickname": "36ers", "urlName": "36ers", "confName": "Intl", "divName": ""}, {"isNBAFranchise": true, "isAllStar": false, "city": "Atlanta", "altCityName": "Atlanta", "fullName": "Atlanta Hawks", "tricode": "ATL", "teamId": "1610612737", "nickname": "Hawks", "urlName": "hawks", "confName": "East", "divName": "Southeast"}, {"isNBAFranchise": false, "isAllStar": false, "city": "Beijing", "altCityName": "Beijing", "fullName": "Beijing Ducks", "tricode": "BJD", "teamId": "15021", "nickname": "Ducks", "urlName": "ducks", "confName": "Intl", "divName": ""}, {"isNBAFranchise": true, "isAllStar": false, "city": "Boston", "altCityName": "Boston", "fullName": "Boston Celtics", "tricode": "BOS", "teamId": "1610612738", "nickname": "Celtics", "urlName": "celtics", "confName": "East", "divName": "Atlantic"}, {"isNBAFranchise": true, "isAllStar": false, "city": "Brooklyn", "altCityN
# ...

# %% [markdown]
# Save with indent

# %%
with open('data_indented.json', 'w+') as outfile:
    json.dump(json_readed, outfile, indent=4)

# %% [markdown]
# Read local json

# %%
with open('data_indented.json', 'r+') as outfile:
    json_readed = json.load(outfile)
json_readed
# Out:
# onfName': 'West',
#     'divName': 'Pacific'},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Guangzhou',
#     'altCityName': 'Guangzhou',
#     'fullName': 'Guangzhou Long-Lions',
#     'tricode': 'GUA',
#     'teamId': '15018',
#     'nickname': 'Long-Lions',
#     'urlName': 'long-lions',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': False,
#     'isAllStar': False,
#     'city': 'Haifa',
#     'altCityName': 'Haifa',
#     'fullName': 'Maccabi Haifa',
#     'tricode': 'MAC',
#     'teamId': '93',
#     'nickname': 'Maccabi Haifa',
#     'urlName': 'maccabi_haifa',
#     'confName': 'Intl',
#     'divName': ''},
#    {'isNBAFranchise': True,
#     'isAllStar': False,
#     'city': 'Houston',
#     'altCityName': 'Houston',
#     'fullName': 'Houston Rockets',
#     'tricode': 'HOU',
#     'teamId': '1610612745',
#     'nickname': 'Rockets',
#     'urlName': 'rockets',
#     'confName': 'West',
#     'divName': 'Southwest'},
# ...

# %%
df_json = pd.read_json("data_indented.json")
df_json
# Out:
#                                           _internal  \
# pubDateTime                 2018-08-30 20:00:04.422
# xslt         xsl/league/roster/marty_teams_list.xsl
# eventName                             league_roster
# standard                                        NaN
# africa                                          NaN
# sacramento                                      NaN
# vegas                                           NaN
# utah                                            NaN
#
#                                                         league
# pubDateTime                                                NaN
# xslt                                                       NaN
# eventName                                                  NaN
# standard     [{'isNBAFranchise': False, 'isAllStar': True, ...
# africa       [{'isNBAFranchise': False, 'isAllStar': False,...
# sacramento   [{'isNBAFranchise': True, 'isAllStar': False, ...
# ...

# %% [markdown]
# ### Data Mining & Data Wrangling
# As you can see, there are jsons inside the original json. For that, we have to mining the json (data mining) to be able to use it correctly (data wrangling).
#
# How do you solve this issue? Research about this and try a solution.

# %%
type(json_readed)
# Out:
# dict

# %%
for elem in json_readed['league']:
    print(elem)
# Out:
# standard
# africa
# sacramento
# vegas
# utah

# %%
new_json = json_readed['league']

with open ('new_json', 'w+') as outfile:
    json.dump(new_json, outfile, indent=4)

df_new_json = pd.read_json("new_json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0972a80372f1> in <module>
#       4     json.dump(new_json, outfile, indent=4)
#       5
# ----> 6 df_new_json = pd.read_json("new_json")
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
# ...

# %%
new_json_1 = new_json["standard"]

with open ('new_json_1', 'w+') as outfile:
    json.dump(new_json_1, outfile, indent=4)

## subdivision standard
df_new_json_1 = pd.read_json("new_json_1")

# %%
df_new_json_1.reset_index()
# Out:
#     index  isNBAFranchise  isAllStar            city         altCityName  \
# 0       0           False       True             USA                 USA
# 1       1           False       True           World               World
# 2       2           False       True            Team                Team
# 3       3           False       True            Team                Team
# 4       4           False       True    Team Giannis        Team Giannis
# 5       5           False       True     Team LeBron         Team LeBron
# 6       6           False      False            Team                Team
# 7       7           False      False            Team                Team
# 8       8           False      False        Adelaide            Adelaide
# 9       9            True      False         Atlanta             Atlanta
# 10     10           False      False         Beijing             Beijing
# 11     11            True      False          Boston              Boston
# ...

# %%
for elem in new_json["africa"]:
    print(elem)
# Out:
# {'isNBAFranchise': False, 'isAllStar': False, 'city': 'Team', 'altCityName': 'Team', 'fullName': 'Team Africa', 'tricode': 'AFR', 'teamId': '12326', 'nickname': 'Africa', 'urlName': 'africa', 'confName': '', 'divName': ''}
# {'isNBAFranchise': False, 'isAllStar': False, 'city': 'Team', 'altCityName': 'Team', 'fullName': 'Team World', 'tricode': 'WLD', 'teamId': '12327', 'nickname': 'World', 'urlName': 'world', 'confName': '', 'divName': ''}

# %%
new_json_2 = new_json["africa"]

with open ('new_json_2', 'w+') as outfile:
    json.dump(new_json_2, outfile, indent=4)

## subdivision africa
df_new_json_2 = pd.read_json("new_json_2")
df_new_json_2.reset_index()
# Out:
#    index  isNBAFranchise  isAllStar  city altCityName     fullName tricode  \
# 0      0           False      False  Team        Team  Team Africa     AFR
# 1      1           False      False  Team        Team   Team World     WLD
#
#    teamId nickname urlName confName divName
# 0   12326   Africa  africa
# 1   12327    World   world

# %%
new_json_3 = new_json["sacramento"]

with open ('new_json_3', 'w+') as outfile:
    json.dump(new_json_3, outfile, indent=4)

## subdivision Sacramento
df_new_json_3 = pd.read_json("new_json_3")
df_new_json_3.reset_index()
# Out:
#    index  isNBAFranchise  isAllStar          city         altCityName  \
# 0      0            True      False  Golden State        Golden State
# 1      1            True      False   Los Angeles  Los Angeles Lakers
# 2      2            True      False         Miami               Miami
# 3      3            True      False    Sacramento          Sacramento
#
#                 fullName tricode      teamId  nickname   urlName    confName  \
# 0  Golden State Warriors     GSW  1610612744  Warriors  warriors  Sacramento
# 1     Los Angeles Lakers     LAL  1610612747    Lakers    lakers  Sacramento
# 2             Miami Heat     MIA  1610612748      Heat      heat  Sacramento
# 3       Sacramento Kings     SAC  1610612758     Kings     kings  Sacramento
#
#   divName
# 0
# 1
# 2
# 3

# %%
new_json_4 = new_json["vegas"]

with open ('new_json_4', 'w+') as outfile:
    json.dump(new_json_4, outfile, indent=4)

## subdivision Vegas
df_new_json_4 = pd.read_json("new_json_4")
df_new_json_4.reset_index()
# Out:
#     index  isNBAFranchise  isAllStar           city         altCityName  \
# 0       0            True      False        Atlanta             Atlanta
# 1       1            True      False         Boston              Boston
# 2       2            True      False       Brooklyn            Brooklyn
# 3       3            True      False      Charlotte           Charlotte
# 4       4            True      False        Chicago             Chicago
# 5       5            True      False      Cleveland           Cleveland
# 6       6            True      False         Dallas              Dallas
# 7       7            True      False         Denver              Denver
# 8       8            True      False        Detroit             Detroit
# 9       9            True      False   Golden State        Golden State
# 10     10            True      False        Houston             Houston
# 11     11            True      False        Indiana             Indiana
# ...

# %%
new_json_5 = new_json["utah"]

with open ('new_json_5', 'w+') as outfile:
    json.dump(new_json_5, outfile, indent=4)

## subdivision utah
df_new_json_5 = pd.read_json("new_json_5")
df_new_json_5.reset_index()
# Out:
#    index  isNBAFranchise  isAllStar         city  altCityName  \
# 0      0            True      False      Atlanta      Atlanta
# 1      1            True      False      Memphis      Memphis
# 2      2            True      False  San Antonio  San Antonio
# 3      3            True      False         Utah         Utah
#
#             fullName tricode      teamId   nickname    urlName confName  \
# 0      Atlanta Hawks     ATL  1610612737      Hawks      hawks     Utah
# 1  Memphis Grizzlies     MEM  1610612763  Grizzlies  grizzlies     Utah
# 2  San Antonio Spurs     SAS  1610612759      Spurs      spurs     Utah
# 3          Utah Jazz     UTA  1610612762       Jazz       jazz     Utah
#
#   divName
# 0
# 1
# 2
# 3

# %%
final_json = pd.concat([df_new_json_1, df_new_json_2, df_new_json_3, df_new_json_4, df_new_json_5], axis=0)

# %%
final_json.reset_index()
final_json.set_index('fullName')
# Out:
#                     isNBAFranchise  isAllStar          city   altCityName  \
# fullName
# USA                          False       True           USA           USA
# World                        False       True         World         World
# All-Stars                    False       True          Team          Team
# All-Stars                    False       True          Team          Team
# Team Giannis                 False       True  Team Giannis  Team Giannis
# ...                            ...        ...           ...           ...
# Washington Wizards            True      False    Washington    Washington
# Atlanta Hawks                 True      False       Atlanta       Atlanta
# Memphis Grizzlies             True      False       Memphis       Memphis
# San Antonio Spurs             True      False   San Antonio   San Antonio
# Utah Jazz                     True      False          Utah          Utah
#
# ...
